# %%
import os

# %%
# 路径配置
file_path = '/root/autodl-tmp/pytorch-CycleGAN-and-pix2pix/checkpoints/3.ResUnet_v3/latest_net_G.pth'

# %%
# 输出模型大小
try:
    # 获取文件大小，单位：字节
    size_in_bytes = os.path.getsize(file_path)
    print(f"文件大小为: {size_in_bytes} 字节")
except FileNotFoundError:
    print(f"错误: 文件 '{file_path}' 不存在")
except OSError as e:
    print(f"无法访问文件: {e}")
# Out:
# 文件大小为: 478223774 字节
